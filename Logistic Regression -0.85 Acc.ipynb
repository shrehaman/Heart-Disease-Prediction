# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"D:\Centurion University\5th Semester\ML for Predictive Analysis\Heart_Disease_Prediction.csv")

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.index[3]
# Out:
# 3

# %%
x_train= df.iloc[:,1:13]

# %%
y_train = df.iloc[:,13:14]

# %%
y_train.head()
# Out:
#   Heart Disease
# 0      Presence
# 1       Absence
# 2      Presence
# 3       Absence
# 4       Absence

# %%
y_train = pd.get_dummies(y_train)

# %%
y_train.head()
# Out:
#    Heart Disease_Absence  Heart Disease_Presence
# 0                      0                       1
# 1                      1                       0
# 2                      0                       1
# 3                      1                       0
# 4                      1                       0

# %%
y_train.shape
# Out:
# (270, 2)

# %%
y_train = y_train.iloc[:,1:2]

# %%
x_train.head()
# Out:
#    Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  Max HR  \
# 0    1                4  130          322             0            2     109
# 1    0                3  115          564             0            2     160
# 2    1                2  124          261             0            0     141
# 3    1                4  128          263             0            0     105
# 4    0                2  120          269             0            2     121
#
#    Exercise angina  ST depression  Slope of ST  Number of vessels fluro  \
# 0                0            2.4            2                        3
# 1                0            1.6            2                        0
# 2                0            0.3            1                        0
# 3                1            0.2            2                        1
# 4                1            0.2            1                        1
#
#    Thallium
# 0         3
# 1         7
# 2         7
# 3         7
# ...

# %%
x_train.shape
# Out:
# (270, 12)

# %%
y_train = np.array(y_train).reshape(270)

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()
scaler.fit(x_train)
scaled = scaler.transform(x_train)
scaled_df = pd.DataFrame(scaled, columns=x_train.columns)

# %%
scaled_df
# Out:
#      Sex  Chest pain type     BP  Cholesterol  FBS over 120  EKG results  \
# 0    1.0             1.00  0.650     0.570922           0.0          1.0
# 1    0.0             0.75  0.575     1.000000           0.0          1.0
# 2    1.0             0.50  0.620     0.462766           0.0          0.0
# 3    1.0             1.00  0.640     0.466312           0.0          0.0
# 4    0.0             0.50  0.600     0.476950           0.0          1.0
# ..   ...              ...    ...          ...           ...          ...
# 265  1.0             0.75  0.860     0.352837           1.0          0.0
# 266  1.0             0.50  0.600     0.466312           0.0          0.0
# 267  0.0             0.50  0.700     0.521277           0.0          1.0
# 268  1.0             1.00  0.700     0.340426           0.0          0.0
# 269  1.0             1.00  0.800     0.507092           0.0          1.0
#
#        Max HR  Exercise angina  ST depression  Slope of ST  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
clf= LogisticRegression(random_state=0).fit(scaled_df,y_train)

# %%
clf.score(scaled_df,y_train)
# Out:
# 0.8518518518518519
